# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('/content/winequality-red.csv')

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
data.shape
# Out:
# (1599, 12)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 1599

# %%
# Список колонок
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# fixed acidity - 0
# volatile acidity - 0
# citric acid - 0
# residual sugar - 0
# chlorides - 0
# free sulfur dioxide - 0
# total sulfur dioxide - 0
# density - 0
# pH - 0
# sulphates - 0
# alcohol - 0
# quality - 0

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
# Определим уникальные значения для целевого признака
data['alcohol'].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.scatterplot(ax=ax, x='fixed acidity', y='volatile acidity', data=data)

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.scatterplot(ax=ax, x='fixed acidity', y='volatile acidity', data=data, hue='alcohol')

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.distplot(data['chlorides'])

# %%
sns.jointplot(x='fixed acidity', y='volatile acidity', data=data, kind="hex")

# %%
sns.boxplot(y=data['total sulfur dioxide'])

# %%
sns.boxplot(x='alcohol', y='volatile acidity', data=data)

# %%
data.corr(method='pearson')
# Out:
#                       fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity              1.000000         -0.256131  ... -0.061668  0.124052
# volatile acidity          -0.256131          1.000000  ... -0.202288 -0.390558
# citric acid                0.671703         -0.552496  ...  0.109903  0.226373
# residual sugar             0.114777          0.001918  ...  0.042075  0.013732
# chlorides                  0.093705          0.061298  ... -0.221141 -0.128907
# free sulfur dioxide       -0.153794         -0.010504  ... -0.069408 -0.050656
# total sulfur dioxide      -0.113181          0.076470  ... -0.205654 -0.185100
# density                    0.668047          0.022026  ... -0.496180 -0.174919
# pH                        -0.682978          0.234937  ...  0.205633 -0.057731
# sulphates                  0.183006         -0.260987  ...  0.093595  0.251397
# alcohol                   -0.061668         -0.202288  ...  1.000000  0.476166
# ...

# %%
data.corr(method='kendall')
# Out:
#                       fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity              1.000000         -0.185197  ... -0.048870  0.087966
# volatile acidity          -0.185197          1.000000  ... -0.151839 -0.300779
# citric acid                0.484271         -0.428354  ...  0.064004  0.167318
# residual sugar             0.155029          0.022407  ...  0.081206  0.025744
# chlorides                  0.176043          0.109608  ... -0.197176 -0.148919
# free sulfur dioxide       -0.119301          0.012573  ... -0.056019 -0.045646
# total sulfur dioxide      -0.056879          0.063701  ... -0.179212 -0.156612
# density                    0.457461          0.015913  ... -0.329754 -0.136611
# pH                        -0.527832          0.158746  ...  0.125311 -0.034235
# sulphates                  0.141343         -0.228888  ...  0.143745  0.299270
# alcohol                   -0.048870         -0.151839  ...  1.000000  0.380367
# ...

# %%
data.corr(method='spearman')
# Out:
#                       fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity              1.000000         -0.278282  ... -0.066576  0.114084
# volatile acidity          -0.278282          1.000000  ... -0.224932 -0.380647
# citric acid                0.661708         -0.610259  ...  0.096456  0.213481
# residual sugar             0.220701          0.032386  ...  0.116548  0.032048
# chlorides                  0.250904          0.158770  ... -0.284504 -0.189922
# free sulfur dioxide       -0.175137          0.021163  ... -0.081367 -0.056901
# total sulfur dioxide      -0.088417          0.094110  ... -0.257806 -0.196735
# density                    0.623071          0.025014  ... -0.462445 -0.177074
# pH                        -0.706674          0.233572  ...  0.179932 -0.043672
# sulphates                  0.212654         -0.325584  ...  0.207330  0.377060
# alcohol                   -0.066576         -0.224932  ...  1.000000  0.478532
# ...

# %%
sns.heatmap(data.corr(), cmap='YlGnBu', annot=True, fmt='.2f')

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
